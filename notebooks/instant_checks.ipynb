# %%
import pandas as pd

# %%
pd.read_parquet(
    "local_code/raw_data/initial_preprocessing/observation_urls/potato_blight_all_observations_urls.parquet")
# Out:
#                                             file_url
# 0  C:\Users\admin\PycharmProjects\tomato dataset\...
# 1  C:\Users\admin\PycharmProjects\tomato dataset\...
# 2  C:\Users\admin\PycharmProjects\tomato dataset\...

# %%
pd.read_parquet("local_code/raw_data/potato_blight/observations/observations_photo_batch_1_cc0_1_200.parquet")
# Out:
# Empty DataFrame
# Columns: [observation_id, time_observed_at_date, observed_on_date, observed_on_year, observed_on_month, observed_on_week, observed_on_day, observed_on_hour, location, place_guess, observed_time_zone, created_time_zone, time_zone_offset, english_common_name, preferred_common_name, taxon_name, description, identifications_most_disagree, identifications_most_agree, quality_grade, uri, image_url, original_image_url, original_width, original_height, license_code, attribution]
# Index: []
#
# [0 rows x 27 columns]

# %%
pd.read_parquet("local_code/raw_data/potato_blight/observations/observations_photo_batch_1_cc-by-nc_99_200.parquet")
# Out:
#      observation_id      time_observed_at_date observed_on_date  \
# 0         250165869                       None       2024-10-10
# 1         250165869                       None       2024-10-10
# 2         250165869                       None       2024-10-10
# 3         250165869                       None       2024-10-10
# 4         249742031                       None       2024-10-19
# ..              ...                        ...              ...
# 282        20774329  2004-06-09T15:01:00-05:00       2004-06-09
# 283        20774329  2004-06-09T15:01:00-05:00       2004-06-09
# 284        20774309  2006-02-07T16:05:00-06:00       2006-02-07
# 285        20774309  2006-02-07T16:05:00-06:00       2006-02-07
# 286        20774309  2006-02-07T16:05:00-06:00       2006-02-07
#
#      observed_on_year  observed_on_month  observed_on_week  observed_on_day  \
# 0                2024                 10                41               10
# ...

# %%
pd.read_parquet("local_code/raw_data/potato_blight/observations/observations_photo_batch_1_cc-by-nc-sa_9_200.parquet")
# Out:
#     observation_id      time_observed_at_date observed_on_date  \
# 0        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 1        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 2        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 3        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 4        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 5        177163857  2023-08-06T13:46:00+10:00       2023-08-06
# 6        162770545  2023-05-20T21:54:00+01:00       2023-05-20
# 7        162770545  2023-05-20T21:54:00+01:00       2023-05-20
# 8        162770545  2023-05-20T21:54:00+01:00       2023-05-20
# 9        147208279  2023-01-20T09:49:28-08:00       2023-01-20
# 10       147208279  2023-01-20T09:49:28-08:00       2023-01-20
# 11       147208279  2023-01-20T09:49:28-08:00       2023-01-20
# 12        99502680  2021-10-16T11:46:00-04:00       2021-10-16
# 13        99502680  2021-10-16T11:46:00-04:00       2021-10-16
# ...

# %%
pd.read_parquet("/local_code/raw_data/page1/failed_licence_urls_cc-by-nc-sa.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_parquet("/local_code/raw_data/page1/failed_licence_urls_cc-by-nc-sa.parquet")
#
# File ~\PycharmProjects\tomato dataset\.venv\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
pd.read_parquet("local_code/raw_data/page1/failed_resource_urls_cc-by-nc-sa.parquet")
# Out:
#                                                  url  status_code
# 0  https://api.inaturalist.org/v1/observations/53...          429

# %%
pd.read_parquet("local_code/raw_data/page2/observations_photo_batch_cc-by_200_200.parquet")
# Out:
#      observation_id      time_observed_at_date observed_on_date  \
# 0         189231095  2023-10-28T10:47:31-04:00       2023-10-28
# 1         189231095  2023-10-28T10:47:31-04:00       2023-10-28
# 2         189155862  2023-10-27T15:59:42-05:00       2023-10-27
# 3         189045680  2023-10-26T15:28:32-04:00       2023-10-26
# 4         189045680  2023-10-26T15:28:32-04:00       2023-10-26
# ..              ...                        ...              ...
# 418       136427569  2022-09-25T16:15:43+02:00       2022-09-25
# 419       136416038  2022-09-25T11:54:15+02:00       2022-09-25
# 420       136416038  2022-09-25T11:54:15+02:00       2022-09-25
# 421       136401478  2022-09-25T17:01:00+10:00       2022-09-25
# 422       136401478  2022-09-25T17:01:00+10:00       2022-09-25
#
#      observed_on_year  observed_on_month  observed_on_week  observed_on_day  \
# 0                2023                 10                43               28
# ...

# %%
pd.read_parquet("local_code/raw_data/tomatoes_data/observations/observations_photo_batch_10_cc-by-nc_200_200.parquet")
# Out:
#      observation_id      time_observed_at_date observed_on_date  \
# 0         189563674  2023-10-31T09:10:26-04:00       2023-10-31
# 1         189563656  2023-10-31T09:10:16-04:00       2023-10-31
# 2         189563649  2023-10-31T09:10:15-04:00       2023-10-31
# 3         189559245  2023-10-30T13:34:00-04:00       2023-10-30
# 4         189551629  2023-10-30T13:17:00+01:00       2023-10-30
# ..              ...                        ...              ...
# 375       185043317  2023-09-26T09:27:53+03:00       2023-09-26
# 376       185026710  2023-09-24T18:24:24-07:00       2023-09-24
# 377       185026710  2023-09-24T18:24:24-07:00       2023-09-24
# 378       185026710  2023-09-24T18:24:24-07:00       2023-09-24
# 379       185023232  2023-09-26T12:30:07-04:00       2023-09-26
#
#      observed_on_year  observed_on_month  observed_on_week  observed_on_day  \
# 0                2023                 10                44               31
# ...

# %%
pd.read_parquet(
    "C:\\Users\\admin\\PycharmProjects\\tomato dataset\\local_code\\raw_data\\initial_preprocessing\\resource_urls\\tomatoes_data_failed_resources.parquet")
# Out:
#                                              file_url
# 0   C:\Users\admin\PycharmProjects\tomato dataset\...
# 1   C:\Users\admin\PycharmProjects\tomato dataset\...
# 2   C:\Users\admin\PycharmProjects\tomato dataset\...
# 3   C:\Users\admin\PycharmProjects\tomato dataset\...
# 4   C:\Users\admin\PycharmProjects\tomato dataset\...
# 5   C:\Users\admin\PycharmProjects\tomato dataset\...
# 6   C:\Users\admin\PycharmProjects\tomato dataset\...
# 7   C:\Users\admin\PycharmProjects\tomato dataset\...
# 8   C:\Users\admin\PycharmProjects\tomato dataset\...
# 9   C:\Users\admin\PycharmProjects\tomato dataset\...
# 10  C:\Users\admin\PycharmProjects\tomato dataset\...
# 11  C:\Users\admin\PycharmProjects\tomato dataset\...
# 12  C:\Users\admin\PycharmProjects\tomato dataset\...
# 13  C:\Users\admin\PycharmProjects\tomato dataset\...
# 14  C:\Users\admin\PycharmProjects\tomato dataset\...
# 15  C:\Users\admin\PycharmProjects\tomato dataset\...
# ...
