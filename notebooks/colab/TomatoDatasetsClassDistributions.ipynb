# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inaturalist_first_part_class_counts = {
  "tomato": 8912,
  "cherry tomato": 361,
  "gargen tomato": 7,
  "other": 69
}

# %%
inaturalist_second_part_class_counts = {
  "tomato": 2681,
  "cherry tomato": 111,
  "gargen tomato": 18
}

# %%
import plotly.express as px

def plot_class_distribution(class_counts, title="Class Distribution"):
    """
    Plots a distribution of classes using a dictionary of class counts.

    Args:
    - class_counts (dict): Dictionary with class names as keys and counts as values.
    - title (str): Title for the plot.

    Returns:
    - None: Displays the plot.
    """
    # Convert the dictionary to a DataFrame for Plotly
    data = {
        "Class": list(class_counts.keys()),
        "Count": list(class_counts.values())
    }

    # Create the bar plot
    fig = px.bar(data,
                 x="Class",
                 y="Count",
                 text="Count",
                 color="Class",
                 title=title,
                 labels={"Class": "Disease Class", "Count": "Number of Images"},
                 color_discrete_sequence=px.colors.qualitative.Plotly)

    # Enhance appearance
    fig.update_traces(texttemplate='%{text}', textposition='outside')
    fig.update_layout(
        xaxis=dict(title="Class", tickangle=45),
        yaxis=dict(title="Count"),
        showlegend=False,
        title=dict(x=0.5),  # Center the title
        height=600,
        width=900
    )

    # Show the plot
    fig.show()

# %%
plot_class_distribution(inaturalist_first_part_class_counts, title="Part1 Class Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_class_distribution(inaturalist_second_part_class_counts, title="Part2 Class Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Step 1: Add values from both dictionaries
merged_class_counts = inaturalist_first_part_class_counts.copy()  # Start with the first dictionary

for key, value in inaturalist_second_part_class_counts.items():
    if key in merged_class_counts:
        merged_class_counts[key] += value  # Add the values if the key exists in both dictionaries
    else:
        merged_class_counts[key] = value  # Add the key-value pair if the key is only in the second dictionary

# Step 2: Print the merged dictionary
print(merged_class_counts)
# Out:
# {'tomato': 11593, 'cherry tomato': 472, 'gargen tomato': 25, 'other': 69}

# %%
plot_class_distribution(merged_class_counts, title="Inaturalist Class Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Evening1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
seperate_ua_evening_class_counts = {
    "Deficiency": 315,
    "Healthy": 184,
    "Late Blight": 137,
    "Leaf Miner": 5,
}

# %%
plot_class_distribution(seperate_ua_evening_class_counts, title="UA evening1 Class Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fused_ua_evening_class_counts = {
    "Deficiency": 315 + 184,
    "Late Blight": 137,
    "Leaf Miner": 5,
}

# %%
plot_class_distribution(fused_ua_evening_class_counts, title="UA evening1 fused(healthy + deficiency) Class Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
